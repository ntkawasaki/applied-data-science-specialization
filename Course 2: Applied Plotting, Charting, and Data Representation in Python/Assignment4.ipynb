# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **religious events or traditions** (see below) for the region of **Los Angeles, California, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Los Angeles, California, United States** to Ann Arbor, USA. In that case at least one source file must be about **Los Angeles, California, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Los Angeles, California, United States** and **religious events or traditions**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **religious events or traditions**?  For this category you might consider calendar events, demographic data about religion in the region and neighboring regions, participation in religious events, or how religious events relate to political events, social movements, or historical events.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

global_ = pd.read_csv('data/global.csv')
national = pd.read_csv('data/national.csv')

# %% [markdown]
# ### Explore the data

# %% [markdown]
# #### National

# %%
national.head()
# Out:
#    year                     state code  christianity_protestant  \
# 0  1945  United States of America  USA                 66069671
# 1  1950  United States of America  USA                 73090083
# 2  1955  United States of America  USA                 79294628
# 3  1960  United States of America  USA                 90692928
# 4  1965  United States of America  USA                 94165803
#
#    christianity_romancatholic  christianity_easternorthodox  \
# 0                    38716742                       1121898
# 1                    42635882                       3045420
# 2                    46402368                       3454916
# 3                    50587880                       3334535
# 4                    64761783                       4792868
#
#    christianity_anglican  christianity_other  christianity_all  \
# 0                2400000             1956807         110265118
# 1                3045420             1177214         122994019
# ...

# %%
national.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1995 entries, 0 to 1994
# Data columns (total 79 columns):
# year                            1995 non-null int64
# state                           1995 non-null object
# code                            1995 non-null object
# christianity_protestant         1995 non-null int64
# christianity_romancatholic      1995 non-null int64
# christianity_easternorthodox    1995 non-null int64
# christianity_anglican           1995 non-null int64
# christianity_other              1995 non-null int64
# christianity_all                1995 non-null int64
# judaism_orthodox                1995 non-null int64
# judaism_conservative            1995 non-null int64
# judaism_reform                  1993 non-null float64
# judaism_other                   1995 non-null int64
# judaism_all                     1995 non-null int64
# islam_sunni                     1995 non-null int64
# islam_shi’a                     1995 non-null int64
# ...

# %%
national.describe()
# Out:
#               year  christianity_protestant  christianity_romancatholic  \
# count  1995.000000             1.995000e+03                1.995000e+03
# mean   1983.388471             2.157768e+06                5.233370e+06
# std      18.768424             9.404066e+06                1.359265e+07
# min    1945.000000             0.000000e+00                0.000000e+00
# 25%    1970.000000             9.727000e+03                4.248550e+04
# 50%    1985.000000             1.207480e+05                4.247680e+05
# 75%    2000.000000             1.015180e+06                3.786475e+06
# max    2010.000000             1.320402e+08                1.273115e+08
#
#        christianity_easternorthodox  christianity_anglican  \
# count                  1.995000e+03           1.995000e+03
# mean                   1.118405e+06           3.731760e+05
# std                    6.573343e+06           2.426476e+06
# min                    0.000000e+00           0.000000e+00
# ...

# %% [markdown]
# #### Global

# %%
global_.head()
# Out:
#    year  christianity_protestant  christianity_romancatholic  \
# 0  1945                160887585                   391332035
# 1  1950                133301043                   401935856
# 2  1955                189347338                   474378130
# 3  1960                220293770                   541957872
# 4  1965                234437703                   614115021
#
#    christianity_easternorthodox  christianity_anglican  christianity_other  \
# 0                      98501171               36955033            13674466
# 1                     106610911               38307544            16324768
# 2                     111661338               38177572            22437724
# 3                     118268109               41846700            44601144
# 4                     125954494               45086639            55119929
#
#    christianity_all  judaism_orthodox  judaism_conservative  judaism_reform  \
# ...

# %%
global_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 76 columns):
# year                            14 non-null int64
# christianity_protestant         14 non-null int64
# christianity_romancatholic      14 non-null int64
# christianity_easternorthodox    14 non-null int64
# christianity_anglican           14 non-null int64
# christianity_other              14 non-null int64
# christianity_all                14 non-null int64
# judaism_orthodox                14 non-null int64
# judaism_conservative            14 non-null int64
# judaism_reform                  14 non-null int64
# judaism_other                   14 non-null int64
# judaism_all                     14 non-null int64
# islam_sunni                     14 non-null int64
# islam_shi’a                     14 non-null int64
# islam_ibadhi                    14 non-null int64
# islam_nationofislam             14 non-null int64
# islam_alawite                   14 non-null int64
# ...

# %%
global_.describe()
# Out:
#               year  christianity_protestant  christianity_romancatholic  \
# count    14.000000             1.400000e+01                1.400000e+01
# mean   1977.500000             3.074819e+08                7.457552e+08
# std      20.916501             1.279905e+08                2.317143e+08
# min    1945.000000             1.333010e+08                3.913320e+08
# 25%    1961.250000             2.238298e+08                5.599972e+08
# 50%    1977.500000             2.719100e+08                7.735803e+08
# 75%    1993.750000             3.902068e+08                9.540931e+08
# max    2010.000000             5.578301e+08                1.049710e+09
#
#        christianity_easternorthodox  christianity_anglican  \
# count                  1.400000e+01           1.400000e+01
# mean                   1.593727e+08           5.317757e+07
# std                    5.968057e+07           1.297891e+07
# min                    9.850117e+07           3.695503e+07
# ...

# %% [markdown]
# Looking at each of the summaries of the datasets, it looks like we have half decade aggregates of total adherents,
# and percentages of population for these religions. They are broken down to the national, regional, and global levels. We can also see that
# some major religions are broken into further classification trees.

# %% [markdown]
# #### Are there any missing values?

# %%
print('National: {}'.format(national.isnull().values.ravel().sum()))
print('Global: {}'.format(global_.isnull().values.ravel().sum()))
# Out:
# National: 5
# Global: 0

# %% [markdown]
# Looks like this data has already had some cleaning done, there are only 5 missing values in the national (most granular) dataset. I will assume these are negligible and ignore them.

# %% [markdown]
# ### How does the relative growth of major religions in the United States compare to the rest of the world (1945 - 2010)?

# %%
usa = national[national['code'] == 'USA'].set_index('year').drop(['state', 'code'], axis=1)
usa.head()
# Out:
#       christianity_protestant  christianity_romancatholic  \
# year
# 1945                 66069671                    38716742
# 1950                 73090083                    42635882
# 1955                 79294628                    46402368
# 1960                 90692928                    50587880
# 1965                 94165803                    64761783
#
#       christianity_easternorthodox  christianity_anglican  christianity_other  \
# year
# 1945                       1121898                2400000             1956807
# 1950                       3045420                3045420             1177214
# 1955                       3454916                2572767             2277091
# 1960                       3334535                2710065             2908939
# 1965                       4792868                2822149              973155
#
#       christianity_all  judaism_orthodox  judaism_conservative  \
# year
# ...

# %%
global_ = global_.set_index('year')
global_
# Out:
#       christianity_protestant  christianity_romancatholic  \
# year
# 1945                160887585                   391332035
# 1950                133301043                   401935856
# 1955                189347338                   474378130
# 1960                220293770                   541957872
# 1965                234437703                   614115021
# 1970                247932230                   671006540
# 1975                264857729                   748325898
# 1980                278962191                   798834729
# 1985                305061321                   865316946
# 1990                391772588                   928527756
# 1995                385509297                   962614859
# 2000                443610594                   978633933
# 2005                490942837                  1013883916
# 2010                557830085                  1049709823
#
#       christianity_easternorthodox  christianity_anglican  christianity_other  \
# ...

# %% [markdown]
# #### What are the major religions in the United States from 1945 - 2010?

# %%
usa_top = usa.filter(regex='_all').mean().sort_values(ascending=False)
usa_top = usa_top.drop('religion_all')
usa_top.head(5)
# Out:
# christianity_all    1.811814e+08
# noreligion_all      3.016089e+07
# judaism_all         5.860115e+06
# buddhism_all        1.641889e+06
# islam_all           1.280548e+06
# dtype: float64

# %% [markdown]
#
# The United States top five religions over the past 65 years are Christianity, No Religion, Judaism, Buddhism, and Islam.
# These will be the five religions I focus on comparing to the rest of the world.

# %% [markdown]
# ### USA

# %%
christianity = usa.christianity_percent
noreligion = usa.noreligion_percent
judaism = usa.judaism_percent
buddhism = usa.buddhism_percent
islam = usa.islam_percent

# %%
plt.figure(figsize=(14,8))

plt.plot(christianity, 'red',
        noreligion, 'blue',
        judaism, 'green', 
        buddhism, 'purple',
        islam, 'yellow')

plt.title('United States Religion Adherence %', color='lightgray', size=15, alpha=0.8)
plt.tick_params(axis='both', color='none', labelcolor='lightgray')

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_facecolor('none')
ax.set_ylim(0, 1)
plt.setp(ax.xaxis.get_majorticklabels(), ha='right')
plt.grid(axis='y', alpha=0.1)

x = plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

plt.show()

# %% [markdown]
# ### Global

# %%
g_christianity = global_.christianity_percent
g_noreligion = global_.noreligion_percent
g_judaism = global_.judaism_percent
g_buddhism = global_.buddhism_percent
g_islam = global_.islam_percent

# %%
plt.figure(figsize=(14,8))

plt.plot(g_christianity, 'red', 
        g_noreligion, 'blue',
        g_judaism, 'green', 
        g_buddhism, 'purple',
        g_islam, 'yellow')

plt.title('Global Religion Adherence %', color='lightgray', size=15)
plt.tick_params(axis='both', color='none', labelcolor='lightgray')

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_facecolor('none')
ax.set_ylim(0, 1)
plt.setp(ax.xaxis.get_majorticklabels(), ha='right')
plt.grid(axis='y', alpha=0.1)

x = plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)
    
# plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Puting both plots into one figure and clean up code

# %%
# Series
christianity = usa.christianity_percent
noreligion = usa.noreligion_percent
judaism = usa.judaism_percent
buddhism = usa.buddhism_percent
islam = usa.islam_percent
usa_data = [christianity, noreligion, judaism, buddhism, islam]

g_christianity = global_.christianity_percent
g_noreligion = global_.noreligion_percent
g_judaism = global_.judaism_percent
g_buddhism = global_.buddhism_percent
g_islam = global_.islam_percent
global_data = [g_christianity, g_noreligion, g_judaism, g_buddhism, g_islam]

all_data = [usa_data, global_data]

# Figure
fig, (ax_usa, ax_global) = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(20, 8), facecolor='#292929')
fig.subplots_adjust(top=0.75)
plt.subplots_adjust(wspace=0.1)

# Plotting variables
colors = ['red', 'blue', 'green', 'purple', 'yellow']
titles = ['United States', 'Global']
labels = ['Christianity', 'No Religion', 'Judaism', 'Buddhism', 'Islam']
axes = [ax_usa, ax_global]

# Figure common title
fig.suptitle("How has the percentage of adherents to the most common \n \
religions in the United States changed from 1945-2010? \n \
(Compare to the rest of the world)", 
             fontsize=20,
            color='lightgray')

# Plot data
# Loop through both axes
for i in range(0, len(axes)):
    ax = axes[i]
    
    # Loop through all series and plot lines on their respective axes
    for j in range(0, len(usa_data)):
        axes[i].plot(all_data[i][j], colors[j])
    
    # Adjustments
    ax.set_title(titles[i], color='lightgray', size=18, alpha=0.8, va='bottom')
    ax.tick_params(axis='both', color='none', labelcolor='lightgray')
    ax.set_facecolor('none')
    ax.set_ylim(0, 1)
    ax.grid(axis='y', alpha=0.1)
    
    # Set all spines to invisible
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)

    # Align tick labels to right
    for tick in ax.xaxis.get_majorticklabels():
        tick.set_horizontalalignment("right")
    
    # Rotate x-axis labels
    xlabels = ax.xaxis.get_ticklabels()
    for item in xlabels:
        item.set_rotation(45)
                
# Add legend
legend = plt.legend(labels=labels, 
                    loc=8, 
                    ncol=5, 
                    fontsize=16, 
                    facecolor='#434343', 
                    bbox_to_anchor=(-0.1,-0.3), 
                    frameon=False)

# Set font color
plt.setp(legend.get_texts(), color='lightgray')

# Increase width of legend markers
for legobj in legend.legendHandles:
    legobj.set_linewidth(5)

# %% [markdown]
# #### Save Image

# %%
fig.savefig('assignment4_image.png', facecolor=fig.get_facecolor(), bbox_inches='tight')
