# %% [markdown]
# # Applied Visualizations

# %% [markdown]
# ## Plotting with Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2']

# %%
plt.style.use('seaborn-colorblind')

# %% [markdown]
# ### DataFrame.plot

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0),
                   'B': np.random.randn(365).cumsum(0) + 20,
                   'C': np.random.randn(365).cumsum(0) - 20}, 
                 index=pd.date_range('1/1/2017', periods=365))
df.head(50)
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638
# 2017-01-06 -0.238765  19.210548 -18.412372
# 2017-01-07 -2.665444  18.621577 -18.964625
# 2017-01-08 -3.094357  19.752729 -19.025419
# 2017-01-09 -1.828421  19.887807 -19.553459
# 2017-01-10 -2.695161  18.675538 -19.692142
# 2017-01-11 -3.374047  19.366315 -19.976389
# 2017-01-12 -3.468756  18.887192 -20.019431
# 2017-01-13 -1.977367  19.247243 -20.072233
# 2017-01-14 -2.616269  19.624163 -20.226438
# 2017-01-15 -3.060251  18.505468 -20.394315
# 2017-01-16 -3.494602  19.295296 -19.085797
# 2017-01-17 -1.288672  18.287787 -18.204380
# 2017-01-18  0.898114  16.982001 -17.316937
# 2017-01-19  1.902168  16.099172 -18.049386
# 2017-01-20  2.288355  15.753082 -16.792565
# 2017-01-21  3.025723  15.862485 -15.660921
# 2017-01-22  4.516455  15.089901 -16.214325
# 2017-01-23  3.580621  15.834721 -14.690473
# 2017-01-24  4.756450  16.086185 -15.373699
# 2017-01-25  3.502570  15.391387 -17.215731
# 2017-01-26  2.864818  16.280380 -16.114205
# 2017-01-27  3.771923  17.441448 -16.233724
# 2017-01-28  2.343243  17.342763 -15.256802
# 2017-01-29  2.203174  17.127780 -16.011004
# 2017-01-30  1.341419  15.354009 -17.272774
# 2017-01-31  1.085800  14.946496 -16.040903
# 2017-02-01 -1.712789  14.654990 -17.448171
# 2017-02-02 -3.484322  14.900369 -19.009202
# 2017-02-03 -4.184200  14.731943 -20.934789
# 2017-02-04 -3.256737  14.975970 -23.729261
# 2017-02-05 -3.430373  16.510060 -24.768365
# 2017-02-06 -3.427527  15.980146 -26.937773
# 2017-02-07 -2.739304  15.489173 -26.973379
# 2017-02-08 -3.618841  14.180008 -29.209796
# 2017-02-09 -3.335213  14.171348 -30.304070
# 2017-02-10 -4.140580  15.148161 -27.972008
# 2017-02-11 -5.868249  13.397090 -27.626883
# 2017-02-12 -6.259149  12.731233 -27.574078
# 2017-02-13 -5.685343  12.767174 -29.194830
# 2017-02-14 -5.346754  13.617277 -29.440427
# 2017-02-15 -5.358585  14.000147 -29.392319
# 2017-02-16 -2.966219  14.325611 -30.997499
# 2017-02-17 -2.553307  14.101298 -30.871319
# 2017-02-18 -1.574571  14.583172 -29.680086
# 2017-02-19  0.663572  15.597476 -30.028344

# %%
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot('A', 'B', kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Size and Color based on value in B column
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
ax.set_aspect('equal')
# The range of A is much smaller than the range of C
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.box();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist(alpha=0.7, edgecolor='lightgray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.kde();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### pandas.plotting

# %%
iris = pd.read_csv('data/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Scatter Matrix
# Compare each column in a DataFrame to every other column in a pairwise fashion

# %%
pd.plotting.scatter_matrix(iris, hist_kwds={'edgecolor':'lightgray'});
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Parallel Coordinates
# Each variable in the dataset corresponds to an equally spaced parallel vertical line. The values of each variable are connected by lines between for each individual observation.
#
# We can see that petal length and petal width split the species clearly. Observe that Iris Virginica has the longest petal length and width, and Iris Setosa has the shortest petal length and width.

# %%
plt.figure()
pd.plotting.parallel_coordinates(iris, 'species');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# Figure aesthetics
# sns.set_style('darkgrid', {"xtick.major.size": 8, "ytick.major.size": 8})

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50,150,5), label='v1', edgecolor='lightgray');
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2', edgecolor='lightgray');
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', edgecolor='lightgray', normed=True)

v3 = np.concatenate((v1, v2))
# Estimates PDF of v3
sns.kdeplot(v3, color='black');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color': 'Teal', 'edgecolor':'lightgray', 'alpha':0.7}, kde_kws={'color': 'Navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Joint Plot
#
# Creates histograms along side a scatter plot.
#
# We can see that v1 and v2 are normally distributed, and have a positive correlation.

# %%
sns.jointplot(v1, v2, alpha=0.8)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid = sns.jointplot(v1, v2, alpha=0.7)
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(v1, v2, kind='hex')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# sns.set_style('white')
sns.jointplot(v1, v2, kind='kde', space=0)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Use iris dataset
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iris, hue='species', diag_kind='kde', palette='viridis', )
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Violin plot

# %%
plt.figure(figsize=(8, 6))
plt.subplot(121)
sns.swarmplot('species', 'petal_length', data=iris)
plt.subplot(122)
sns.violinplot('species', 'petal_length', data=iris)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Spurious Correlations

# %% [markdown]
# ### link: http://www.tylervigen.com/spurious-correlations
